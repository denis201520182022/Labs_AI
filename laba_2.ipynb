# %% [markdown]
# # Практическая работа 2. Основные конструкции языка
#
#
# Котляров Денис Владимирович
# ПИН-б-о-22-1 09.03.03 Прикладная информатика

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = [1.0, 2.0, 3.4, 4.11, "g", 23, 24,25,436,3,3.4, 4.3, 3.5]
b = 0
a = 0
p1 = []
for i in range(len(p)):
    j = p[i]
    p1.append(j)
    if type(j) == float:
        a += 1
        if a == 3 and ((j < p[i-1])and(p[i-1]>p[i-2])):

            b += 1
        if a>3 and ((j < p[i-1])and(p[i-1]>p[i-2])):
            a=3
            b += 1
    else:
        a = 0
    print(type(j), a, b, sep=' | ')
print("Колличество троек вещественных чисел:", b)
print(p)
print(p1)
# Out:
# <class 'float'> | 1 | 0
# <class 'float'> | 2 | 0
# <class 'float'> | 3 | 0
# <class 'float'> | 4 | 0
# <class 'str'> | 0 | 0
# <class 'int'> | 0 | 0
# <class 'int'> | 0 | 0
# <class 'int'> | 0 | 0
# <class 'int'> | 0 | 0
# <class 'int'> | 0 | 0
# <class 'float'> | 1 | 0
# <class 'float'> | 2 | 0
# <class 'float'> | 3 | 1
# Колличество троек вещественных чисел: 1
# [1.0, 2.0, 3.4, 4.11, 'g', 23, 24, 25, 436, 3, 3.4, 4.3, 3.5]
# [1.0, 2.0, 3.4, 4.11, 'g', 23, 24, 25, 436, 3, 3.4, 4.3, 3.5]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Это циклы: for, while
# 2. for, if, else, =
# 3. sep — позволяет задать разделитель, который будет выводиться между элементами, переданными в функцию print(). По умолчанию разделителем является пробел, но с помощью sep пробел можно заменить на другой разделитель, например, на запятую.
# end — определяет символ, который будет добавлен в конец сообщения после вывода. По умолчанию это символ перевода строки.
# file — позволяет перенаправить вывод текста в нужный файл. По умолчанию функция выводит текст в консоль.
# flush — позволяет управлять буферизацией вывода. Если этот аргумент установлен в True, то вывод не будет буферизоваться и будет выводиться немедленно.
# 4. Список в Python - это коллекция элементов произвольного типа, разделенных запятыми.
# 5. С помощью индекса можно обращаться к элементам списка
# 6. Размер. Массивы имеют фиксированный размер, установленный при создании, в то время как списки динамичны и могут меняться по размеру в процессе выполнения. 1
# Типы данных. Все элементы в массиве должны иметь один и тот же тип данных, в то время как списки могут содержать элементы различных типов данных.
